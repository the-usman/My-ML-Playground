# %%
import pandas as pd
import numpy as np

# %%
df = pd.read_csv('data/fake_job_postings.csv', index_col=[0])
df.sample(5)
# Out:
#                                                     title
# job_id
# 8884    M1 Apprentice Office Administrator Under NAS 1...  \
# 17070                                        Title Closer
# 15380                 Supply Chain & Logistics Specialist
# 8094                          Customer Service Associate
# 4234                         Marketing Manager SEM France
#
#                        location             department salary_range
# job_id
# 8884        GB, MAN, Manchester                    NaN          NaN  \
# 17070         US, FL, Tampa Bay                    NaN          NaN
# 15380   US, FL, Fort Lauderdale                    NaN          NaN
# 8094           US, OR, Portland                    NaN          NaN
# 4234             DE, BE, Berlin  Performance Marketing          NaN
#
#                                           company_profile
# job_id
# 8884    Established on the principles that full time e...  \
# 17070   Network Closing Services has been serving Lend...
# ...
